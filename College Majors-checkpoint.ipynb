# %%
import pandas as pd
import matplotlib as mpl
import pandas.plotting
recent_grads = pd.read_csv("CollegeMajors.csv")

# %%
# %matplotlib inline

# %%
print(recent_grads.iloc[0])
recent_grads.head()
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
raw_data_count = recent_grads.count()
raw_data_count
# Out:
# Rank                    173
# Major_code              173
# Major                   173
# Total                   172
# Men                     172
# Women                   172
# Major_category          173
# ShareWomen              172
# Sample_size             173
# Employed                173
# Full_time               173
# Part_time               173
# Full_time_year_round    173
# Unemployed              173
# Unemployment_rate       173
# Median                  173
# P25th                   173
# P75th                   173
# College_jobs            173
# Non_college_jobs        173
# Low_wage_jobs           173
# dtype: int64

# %%
recent_grads = recent_grads.dropna()
recent_grads.count()
# Out:
# Rank                    172
# Major_code              172
# Major                   172
# Total                   172
# Men                     172
# Women                   172
# Major_category          172
# ShareWomen              172
# Sample_size             172
# Employed                172
# Full_time               172
# Part_time               172
# Full_time_year_round    172
# Unemployed              172
# Unemployment_rate       172
# Median                  172
# P25th                   172
# P75th                   172
# College_jobs            172
# Non_college_jobs        172
# Low_wage_jobs           172
# dtype: int64

# %%
cleaned_data_count = recent_grads.count()

# %% [markdown]
# ## Plots

# %%
samp_med = recent_grads.plot(x= 'Median', y= 'Sample_size', kind= 'scatter', figsize=(5,5))

# %% [markdown]
# The bigger the samples, the smaller variability in the medians (earnings of full-time, year-round workers). Getting closer to 40,000

# %%
samp_un = recent_grads.plot(x= 'Unemployment_rate', y= 'Sample_size', kind= 'scatter', figsize=(4,4))

# %% [markdown]
# The same happens with unemployment rate. The bigger the sample the more you can see the limits. Mainly from 5% to 10%

# %%
full_med = recent_grads.plot(x= 'Median', y= 'Full_time', kind= 'scatter', figsize=(6,5))

# %%
recent_grads['Median'].describe()
# Out:
# count       172.000000
# mean      40076.744186
# std       11461.388773
# min       22000.000000
# 25%       33000.000000
# 50%       36000.000000
# 75%       45000.000000
# max      110000.000000
# Name: Median, dtype: float64

# %% [markdown]
# The more people with full time jobs the closer the median to 40,000$

# %%
recent_grads['ShareMen'] = (recent_grads['ShareWomen'] - 1)*-1

# %%
wo_unemp = recent_grads.plot(x= 'ShareWomen', y= 'Unemployment_rate', kind= 'scatter', figsize=(4,4))

# %% [markdown]
# There is no visible correlation between unemployment rate and Women major's share.

# %%
men_med = recent_grads.plot(x= 'Median', y= 'Men', kind= 'scatter', figsize=(5,4))

# %%
wo_med = recent_grads.plot(x= 'Median', y= 'Women', kind= 'scatter', figsize=(5,4))

# %% [markdown]
# Comparing both scatter, we can see mean sallaries look similar.
# There is an visual difference in the men curve which extends 10,000 to 20,000USD more than women in majors between 125,000 and 50,000 men/women

# %% [markdown]
# ## Histograms

# %%
recent_grads['Sample_size'].hist(bins = 16, range= (0,800),grid=False)
print(recent_grads['Sample_size'].describe())
# Out:
# count     172.000000
# mean      357.941860
# std       619.680419
# min         2.000000
# 25%        42.000000
# 50%       131.000000
# 75%       339.000000
# max      4212.000000
# Name: Sample_size, dtype: float64

# %%
recent_grads['Sample_size_pctg'] = (recent_grads['Sample_size'])/(recent_grads['Total'])*100
print(recent_grads['Sample_size_pctg'].describe())
# Out:
# count    172.000000
# mean       0.909073
# std        0.381933
# min        0.161352
# 25%        0.660213
# 50%        0.880854
# 75%        1.121023
# max        3.225806
# Name: Sample_size_pctg, dtype: float64

# %% [markdown]
# There is an easily visible Sample Size curve. With the most frequency being between 0 to 50 people sampled.
#
# The **sample/total people enrolled** formula is high, which means the data was well gathered with good samples.

# %%
recent_grads['Median'].hist(bins= 20, grid=False, range= (20000,80000))

# %% [markdown]
# Most new-grads earn between 30,000 to 40,000USD

# %%
recent_grads['Employed_pctg'] = (recent_grads['Employed'])/(recent_grads['Total'])*(100)

# %%
recent_grads['Employed_pctg'].hist(bins= 20, grid=False, range= (0,100))

# %% [markdown]
# Most majors have employment rates from 70% to 90%

# %%
recent_grads['Full_time_pctg'] = (recent_grads['Full_time'])/(recent_grads['Total'])*(100)
recent_grads['Full_time_pctg'].hist(bins= 20, grid=False, range=(0,100))

# %% [markdown]
# 60 to 80 % are in full time jobs

# %%
recent_grads['ShareWomen'].hist(bins= 5, grid=False)

# %% [markdown]
# 48% of Majors have mor men than women

# %%
recent_grads['Unemployment_rate'].hist(bins= 10, grid=False)

# %% [markdown]
# Unemployment mainly ranges from 2.5% to 12.5%

# %%
pd.plotting.scatter_matrix(recent_grads[['Sample_size','Median']], figsize = (8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E4D00B4518>,
# ...
#       dtype=object)

# %%
pd.plotting.scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']], figsize = (8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E4D025DC88>,
# ...
#       dtype=object)

# %%
recent_grads[:10]['ShareWomen'].plot(kind = 'bar')

# %%
recent_grads[-10:]['ShareWomen'].plot(kind = 'bar')

# %% [markdown]
# We can see there is a big difference in women to men ratio between the top 5 Majors and the bottom 5

# %%
recent_grads[:10]['Unemployment_rate'].plot(kind = 'bar')

# %%
recent_grads[-10:]['Unemployment_rate'].plot(kind = 'bar')

# %% [markdown]
# There is a small visual difference in unemployment rate between the top 5 and bottom 5 majors
